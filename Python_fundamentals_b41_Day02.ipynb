# %%
#Understanding the variables in python.

# %%
#Variables are place holders for which values will be assigned.

# %%
x=2
y=3
x+y
# Out:
# 5

# %%
#Rules for declaring the variables:
#Rule No:1 A variable should not have names spaces

# %%
first name='rahul'
# Out:
#   File "<ipython-input-2-a8d593627008>", line 1
#     first name='rahul'
#           ^
# SyntaxError: invalid syntax

# %%
#right way of declaring variables
first_name='Fairoz';
print (first_name)
# Out:
# Fairoz

# %%
#Rule No:2 A variable name should not start with a number but can end with a number or can have number in middle 
1name='Rajesh'
print (1name)
# Out:
#   File "<ipython-input-5-fe7378b8570b>", line 2
#     1name='Rajesh'
#      ^
# SyntaxError: invalid syntax

# %%
#Special charecters or numbers can be used in the middle or at the endabs
name1='Rizwan'
name_2='Naveen'
print(name1)
print(name_2)
# Out:
# Rizwan
# Naveen

# %%
#Rule No:3 A variable name should not contain any special charecter
sport@1='football'
print (sport@1)
# Out:
#   File "<ipython-input-7-0d701d96603e>", line 2
#     sport@1='football'
#     ^
# SyntaxError: cannot assign to operator

# %%
#Introduction to datatypes in python
    #1. Strings 	-----> str
    #2. Numbers	-----> integers --> int and floats --> float (decimals)
    #3. list 	-----> list
    #4. tuple 	-----> tuple
    #5. Dictionaries -> dict

#Classification of datatypes
    #1-> mutable datatypes
    #2-> immutable datatypes
    
##mutable datatypes => which we can edit or alter
##immutable datatypes -> we cant edit or alter

# %%
#Introduction to String Datatypes:
#definition: A string is nothing but a series of charecters declared in quotes
#classification: It is classified as immutable datatypes.
        #how to declare a string 	----> 3 possible ways
        #1. Single quotes
        #2. Double quotes
        #3. triple quotes

# %%
#Introduction to String Methods:
    #These are builtin programs which we can use 
    #it will be validating the datatype.

# %%
namex='Cricket'
namey='football'

type(namex)
# Out:
# str

# %%
type(namey)
# Out:
# str
